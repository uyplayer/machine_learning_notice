# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('MARUTI.csv')
df.head(5)
# Out:
#          Date  Symbol Series  Prev Close    Open    High     Low   Last  \
# 0  2003-07-09  MARUTI     EQ      125.00  164.90  170.40  155.00  164.0
# 1  2003-07-10  MARUTI     EQ      164.30  167.00  168.70  164.50  167.0
# 2  2003-07-11  MARUTI     EQ      167.00  167.75  174.85  166.25  173.6
# 3  2003-07-14  MARUTI     EQ      173.35  174.25  179.25  174.25  178.6
# 4  2003-07-15  MARUTI     EQ      177.95  200.00  200.00  173.00  176.3
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  164.30  165.95  35164283  5.835528e+14     NaN           8537695.0
# 1  167.00  166.74  10464179  1.744820e+14     NaN           4363947.0
# 2  173.35  172.45  11740117  2.024622e+14     NaN           3014852.0
# 3  177.95  177.91   5982324  1.064313e+14     NaN           1949217.0
# 4  176.20  176.88   6173689  1.092001e+14     NaN           1307694.0
#
#    %Deliverble
# 0       0.2428
# 1       0.4170
# 2       0.2568
# 3       0.3258
# 4       0.2118

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4218.000000  4218.000000  4218.000000  4218.000000  4218.000000
# mean   2720.774443  2724.318836  2757.088182  2688.606508  2721.875154
# std    2645.137769  2649.336690  2672.173068  2621.579014  2645.140686
# min     125.000000   164.000000   168.700000   155.000000   164.000000
# 25%     806.212500   808.250000   822.000000   790.100000   806.100000
# 50%    1373.525000  1373.825000  1393.950000  1355.300000  1374.125000
# 75%    4362.275000  4380.000000  4449.525000  4317.525000  4369.075000
# max    9832.450000  9966.000000  9996.400000  9725.000000  9846.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  4218.000000  4218.000000  4.218000e+03  4.218000e+03    2247.000000
# mean   2722.128947  2723.300239  1.197247e+06  2.117123e+14   51340.773921
# std    2645.271038  2646.841452  1.674455e+06  2.604774e+14   42554.293144
# min     164.300000   165.060000  2.279600e+04  2.131518e+12    1096.000000
# 25%     806.262500   805.852500  4.168292e+05  6.069819e+13   21491.500000
# 50%    1373.725000  1375.240000  6.711405e+05  1.049696e+14   40213.000000
# 75%    4368.925000  4371.577500  1.197491e+06  2.742523e+14   65138.000000
# max    9832.450000  9850.960000  3.516428e+07  4.878992e+15  407715.000000
#
#        Deliverable Volume  %Deliverble
# count        4.217000e+03  4217.000000
# mean         3.649973e+05     0.392807
# std          3.746657e+05     0.157400
# min          4.896000e+03     0.034300
# 25%          1.603160e+05     0.276100
# 50%          2.706580e+05     0.396600
# 75%          4.510900e+05     0.506000
# max          8.537695e+06     1.000000

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
data = df[['Date','Open','High','Low','Close','Volume','VWAP']]

# %%
data
# Out:
#             Date     Open     High      Low    Close    Volume     VWAP
# 0     2003-07-09   164.90   170.40   155.00   164.30  35164283   165.95
# 1     2003-07-10   167.00   168.70   164.50   167.00  10464179   166.74
# 2     2003-07-11   167.75   174.85   166.25   173.35  11740117   172.45
# 3     2003-07-14   174.25   179.25   174.25   177.95   5982324   177.91
# 4     2003-07-15   200.00   200.00   173.00   176.20   6173689   176.88
# ...          ...      ...      ...      ...      ...       ...      ...
# 4213  2020-06-24  5938.00  5938.00  5730.00  5755.35   1268492  5828.53
# 4214  2020-06-25  5677.00  5846.80  5651.00  5762.30   1266213  5778.04
# 4215  2020-06-26  5800.00  5810.00  5695.00  5754.90   1063059  5736.35
# 4216  2020-06-29  5730.00  5800.00  5650.00  5678.70   1102655  5702.69
# 4217  2020-06-30  5750.00  5874.50  5681.45  5838.30   2015839  5806.09
#
# [4218 rows x 7 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of                Open     High      Low    Close    Volume     VWAP
# Date
# 2003-07-09   164.90   170.40   155.00   164.30  35164283   165.95
# 2003-07-10   167.00   168.70   164.50   167.00  10464179   166.74
# 2003-07-11   167.75   174.85   166.25   173.35  11740117   172.45
# 2003-07-14   174.25   179.25   174.25   177.95   5982324   177.91
# 2003-07-15   200.00   200.00   173.00   176.20   6173689   176.88
# ...             ...      ...      ...      ...       ...      ...
# 2020-06-24  5938.00  5938.00  5730.00  5755.35   1268492  5828.53
# 2020-06-25  5677.00  5846.80  5651.00  5762.30   1266213  5778.04
# 2020-06-26  5800.00  5810.00  5695.00  5754.90   1063059  5736.35
# 2020-06-29  5730.00  5800.00  5650.00  5678.70   1102655  5702.69
# 2020-06-30  5750.00  5874.50  5681.45  5838.30   2015839  5806.09
#
# [4218 rows x 6 columns]>

# %%
data['Date'] = data['Date'].apply(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-db406af5b4d1> in <module>
# ----> 1 data['Date'] = data['Date'].apply(pd.to_datetime)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

# %%
data['Date'] = data['Date'].apply(pd.to_datetime)
data.set_index('Date',inplace=True)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-f6ed39fc7195> in <module>
# ----> 1 data['Date'] = data['Date'].apply(pd.to_datetime)
#       2 data.set_index('Date',inplace=True)
#       3 data.head()
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

# %%
data['Volume'].plot(figsize=(10,5),title='Maruti Stock Prices')
plt.ylabel('VWAP')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8a7725e82dec> in <module>
#       1 data['Volume'].plot(figsize=(10,5),title='Maruti Stock Prices')
# ----> 2 plt.ylabel('VWAP')
#
# NameError: name 'plt' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-aef4b177b473> in <module>
# ----> 1 Text(0, 0.5, 'VWAP')
#
# NameError: name 'Text' is not defined

# %%
from datetime import datetime
my_year = 2019
my_month = 4
my_day = 21
my_hour = 10
my_minute = 5
my_second = 30

# %%
test_date = datetime(my_year, my_month, my_day)
test_date
# Out:
# datetime.datetime(2019, 4, 21, 0, 0)

# %%
test_date = datetime(my_year,my_month,my_day,my_hour,my_minute,my_second)
test_date
# Out:
# datetime.datetime(2019, 4, 21, 10, 5, 30)

# %%
print('The day is : ', test_date.day)
print('The hour is : ', test_date.hour)
print('The month is : ', test_date.month)
# Out:
# The day is :  21
# The hour is :  10
# The month is :  4

# %%
data
# Out:
#                Open     High      Low    Close    Volume     VWAP
# Date
# 2003-07-09   164.90   170.40   155.00   164.30  35164283   165.95
# 2003-07-10   167.00   168.70   164.50   167.00  10464179   166.74
# 2003-07-11   167.75   174.85   166.25   173.35  11740117   172.45
# 2003-07-14   174.25   179.25   174.25   177.95   5982324   177.91
# 2003-07-15   200.00   200.00   173.00   176.20   6173689   176.88
# ...             ...      ...      ...      ...       ...      ...
# 2020-06-24  5938.00  5938.00  5730.00  5755.35   1268492  5828.53
# 2020-06-25  5677.00  5846.80  5651.00  5762.30   1266213  5778.04
# 2020-06-26  5800.00  5810.00  5695.00  5754.90   1063059  5736.35
# 2020-06-29  5730.00  5800.00  5650.00  5678.70   1102655  5702.69
# 2020-06-30  5750.00  5874.50  5681.45  5838.30   2015839  5806.09
#
# [4218 rows x 6 columns]

# %%
print(data.index.max())
print(data.index.min())
# Out:
# 2020-06-30 00:00:00
# 2003-07-09 00:00:00

# %%
# Earliest date index location
print('Earliest date index location is: ',data.index.argmin())

# Latest date location
print('Latest date location: ',data.index.argmax())
# Out:
# Earliest date index location is:  0
# Latest date location:  4217

# %%
df_vwap = df[['Date','VWAP']]
df_vwap['Date'] = df_vwap['Date'].apply(pd.to_datetime)
df_vwap.set_index("Date", inplace = True)
df_vwap.head()
# Out:
# /home/uyplayer/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               VWAP
# Date
# 2003-07-09  165.95
# 2003-07-10  166.74
# 2003-07-11  172.45
# 2003-07-14  177.91
# 2003-07-15  176.88

# %%
vwap_subset = df_vwap['2017':'2020']

vwap_subset
vwap_subset = df_vwap['2017-01':'2020-12']
vwap_subset

vwap_subset = df_vwap['2017-01-01':'2020-12-15']
vwap_subset
# Out:
#                VWAP
# Date
# 2017-01-02  5386.21
# 2017-01-03  5485.36
# 2017-01-04  5521.15
# 2017-01-05  5600.23
# 2017-01-06  5616.11
# ...             ...
# 2020-06-24  5828.53
# 2020-06-25  5778.04
# 2020-06-26  5736.35
# 2020-06-29  5702.69
# 2020-06-30  5806.09
#
# [862 rows x 1 columns]

# %%
vwap_subset.count()
# Out:
# VWAP    862
# dtype: int64

# %%
ax = vwap_subset.plot(color='blue',fontsize=14)
ax.set_xlabel('Date')
ax.set_ylabel('VWAP')

ax.axvspan('2019-01-01','2019-01-31', color='red', alpha=0.3)
ax.axhspan(6500,7000, color='green',alpha=0.3)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-ae9b0ac3168e> in <module>
#       6 ax.axhspan(6500,7000, color='green',alpha=0.3)
#       7
# ----> 8 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df_vwap
# Out:
#                VWAP
# Date
# 2003-07-09   165.95
# 2003-07-10   166.74
# 2003-07-11   172.45
# 2003-07-14   177.91
# 2003-07-15   176.88
# ...             ...
# 2020-06-24  5828.53
# 2020-06-25  5778.04
# 2020-06-26  5736.35
# 2020-06-29  5702.69
# 2020-06-30  5806.09
#
# [4218 rows x 1 columns]

# %%
import seaborn as sns

# %%
sns.kdeplot(df_vwap["VWAP"],shade=True)

# %%
df_vwap['VWAP'].plot(figsize=(16,8),title=' volume weighted average price')

# %%
 df_vwap.loc['2018', 'VWAP']
# Out:
# Date
# 2018-01-01    9708.58
# 2018-01-02    9595.64
# 2018-01-03    9473.05
# 2018-01-04    9414.19
# 2018-01-05    9467.87
#                ...
# 2018-12-24    7533.81
# 2018-12-26    7507.34
# 2018-12-27    7575.64
# 2018-12-28    7529.16
# 2018-12-31    7516.95
# Name: VWAP, Length: 246, dtype: float64

# %%
ax = df_vwap.loc['2018', 'VWAP'].plot(figsize=(15,6))
ax.set_title('Month-wise Trend in 2018'); 
ax.set_ylabel('VWAP');
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-2eda6aea9190> in <module>
#       2 ax.set_title('Month-wise Trend in 2018');
#       3 ax.set_ylabel('VWAP');
# ----> 4 ax.xaxis.set_major_locator(mdates.MonthLocator())
#       5 ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'));
#
# NameError: name 'mdates' is not defined

# %%
ax = df_vwap.loc['2018-10':'2018-11','VWAP'].plot(marker='o', linestyle='-',figsize=(15,6))
ax.set_title('Oct-Nov 2018 trend'); 
ax.set_ylabel('VWAP');
ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MONDAY))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-16b7e860ba8a> in <module>
#       2 ax.set_title('Oct-Nov 2018 trend');
#       3 ax.set_ylabel('VWAP');
# ----> 4 ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MONDAY))
#       5 ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'));
#
# NameError: name 'mdates' is not defined

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (10,10)})
y = df_vwap['VWAP'].to_frame()
y

# # Multiplicative Decomposition 
result_mul = seasonal_decompose(y, model='multiplicative',freq = 52)
result_mul
# # Additive Decomposition
result_add = seasonal_decompose(y, model='additive',freq = 52)
result_add
# # Plot
plt.rcParams.update({'figure.figsize': (10,10)})
result_mul.plot().suptitle('Multiplicative Decompose', fontsize=22)
result_add.plot().suptitle('Additive Decompose', fontsize=22)
plt.show()
# Out:
# /home/uyplayer/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: the 'freq' keyword is deprecated, use 'period' instead
#
# /home/uyplayer/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: the 'freq' keyword is deprecated, use 'period' instead
#   if __name__ == '__main__':

# %%
# Actual Values = Product of (Seasonal * Trend * Resid)
df_reconstructed = pd.concat([result_add.seasonal, result_add.trend, result_add.resid, result_add.observed], axis=1)
df_reconstructed.columns = ['seas', 'trend', 'resid', 'actual_values']
df_reconstructed.tail()
# Out:
#                 seas  trend  resid  actual_values
# Date
# 2020-06-24 -6.820483    NaN    NaN        5828.53
# 2020-06-25 -2.009366    NaN    NaN        5778.04
# 2020-06-26 -2.577852    NaN    NaN        5736.35
# 2020-06-29 -5.130197    NaN    NaN        5702.69
# 2020-06-30 -3.545324    NaN    NaN        5806.09

# %%
df_vwap.Date.dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-23d9b0bf55e3> in <module>
# ----> 1 df_vwap.Date.dt.year
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df_vwap.reset_index(inplace=True)
df_vwap['year'] = df_vwap.Date.dt.year
df_vwap['month'] = df_vwap.Date.dt.month
df_vwap['day'] = df_vwap.Date.dt.day
df_vwap['day of week'] = df_vwap.Date.dt.dayofweek
df_vwap['Weekday Name'] = df_vwap.Date.dt.weekday_name

#Set Date column as the index column.
df_vwap.set_index('Date', inplace=True)
df_vwap.head()
# Out:
# /home/uyplayer/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/uyplayer/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/uyplayer/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/uyplayer/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/uyplayer/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             index    VWAP  year  month  day  day of week Weekday Name
# Date
# 2003-07-09      0  165.95  2003      7    9            2    Wednesday
# 2003-07-10      1  166.74  2003      7   10            3     Thursday
# 2003-07-11      2  172.45  2003      7   11            4       Friday
# 2003-07-14      3  177.91  2003      7   14            0       Monday
# 2003-07-15      4  176.88  2003      7   15            1      Tuesday

# %%
df_vwap.resample(rule='A').mean()
# Out:
#              index         VWAP    year     month        day  day of week
# Date
# 2003-12-31    61.5   266.608468  2003.0  9.604839  16.298387     2.016129
# 2004-12-31   250.5   430.522835  2004.0  6.559055  15.708661     2.047244
# 2005-12-31   503.0   494.328566  2005.0  6.541833  15.733068     2.000000
# 2006-12-31   753.5   845.582160  2006.0  6.552000  15.976000     2.056000
# 2007-12-31  1003.0   887.107871  2007.0  6.554217  15.843373     1.987952
# 2008-12-31  1250.5   702.865285  2008.0  6.443089  15.821138     1.955285
# 2009-12-31  1495.0  1126.175638  2009.0  6.580247  15.761317     2.041152
# 2010-12-31  1742.5  1377.567540  2010.0  6.599206  15.710317     1.992063
# 2011-12-31  1992.0  1163.060891  2011.0  6.502024  15.829960     1.995951
# 2012-12-31  2241.0  1266.256335  2012.0  6.438247  15.784861     2.047809
# 2013-12-31  2491.5  1515.124520  2013.0  6.472000  15.672000     2.004000
# 2014-12-31  2738.5  2467.851189  2014.0  6.446721  15.844262     1.983607
# 2015-12-31  2984.5  4037.128347  2015.0  6.508065  15.826613     1.967742
# 2016-12-31  3232.0  4515.793401  2016.0  6.546559  15.761134     2.056680
# 2017-12-31  3479.5  7236.069516  2017.0  6.528226  15.758065     2.012097
# 2018-12-31  3726.5  8564.463659  2018.0  6.467480  15.731707     1.955285
# 2019-12-31  3972.0  6790.216490  2019.0  6.465306  15.897959     2.057143
# 2020-12-31  4156.0  5908.417805  2020.0  3.455285  15.886179     2.016260

# %%
plt.rcParams['figure.figsize'] = (8, 6)
df_vwap['VWAP'].resample('A').mean().plot(kind='bar')
plt.title('Yearly Mean VWAP for Maruti')
# Out:
# Text(0.5,1,'Yearly Mean VWAP for Maruti')

# %%
df_vwap['VWAP'].resample('AS').mean().plot(kind='bar',figsize = (10,4))
plt.title('Yearly start Mean VWAP for Maruti')
# Out:
# Text(0.5,1,'Yearly start Mean VWAP for Maruti')

# %%
df_vwap.head()
# Out:
#             index    VWAP  year  month  day  day of week Weekday Name
# Date
# 2003-07-09      0  165.95  2003      7    9            2    Wednesday
# 2003-07-10      1  166.74  2003      7   10            3     Thursday
# 2003-07-11      2  172.45  2003      7   11            4       Friday
# 2003-07-14      3  177.91  2003      7   14            0       Monday
# 2003-07-15      4  176.88  2003      7   15            1      Tuesday

# %%
df_vwap.shift(1).head()
# Out:
#             index    VWAP    year  month   day  day of week Weekday Name
# Date
# 2003-07-09    NaN     NaN     NaN    NaN   NaN          NaN          NaN
# 2003-07-10    0.0  165.95  2003.0    7.0   9.0          2.0    Wednesday
# 2003-07-11    1.0  166.74  2003.0    7.0  10.0          3.0     Thursday
# 2003-07-14    2.0  172.45  2003.0    7.0  11.0          4.0       Friday
# 2003-07-15    3.0  177.91  2003.0    7.0  14.0          0.0       Monday

# %%
df_vwap.shift(-1).head()
# Out:
#             index    VWAP    year  month   day  day of week Weekday Name
# Date
# 2003-07-09    1.0  166.74  2003.0    7.0  10.0          3.0     Thursday
# 2003-07-10    2.0  172.45  2003.0    7.0  11.0          4.0       Friday
# 2003-07-11    3.0  177.91  2003.0    7.0  14.0          0.0       Monday
# 2003-07-14    4.0  176.88  2003.0    7.0  15.0          1.0      Tuesday
# 2003-07-15    5.0  177.59  2003.0    7.0  16.0          2.0    Wednesday

# %%
df_vwap.tshift(periods=3, freq = 'M').head()
# Out:
#             index    VWAP  year  month  day  day of week Weekday Name
# Date
# 2003-09-30      0  165.95  2003      7    9            2    Wednesday
# 2003-09-30      1  166.74  2003      7   10            3     Thursday
# 2003-09-30      2  172.45  2003      7   11            4       Friday
# 2003-09-30      3  177.91  2003      7   14            0       Monday
# 2003-09-30      4  176.88  2003      7   15            1      Tuesday

# %%
df_vwap['VWAP'].plot(figsize = (10,6))

# %%
df_vwap.rolling(7).mean().head(10)
# Out:
#             index        VWAP    year  month        day  day of week
# Date
# 2003-07-09    NaN         NaN     NaN    NaN        NaN          NaN
# 2003-07-10    NaN         NaN     NaN    NaN        NaN          NaN
# 2003-07-11    NaN         NaN     NaN    NaN        NaN          NaN
# 2003-07-14    NaN         NaN     NaN    NaN        NaN          NaN
# 2003-07-15    NaN         NaN     NaN    NaN        NaN          NaN
# 2003-07-16    NaN         NaN     NaN    NaN        NaN          NaN
# 2003-07-17    3.0  173.285714  2003.0    7.0  13.142857     2.142857
# 2003-07-18    4.0  173.530000  2003.0    7.0  14.428571     2.428571
# 2003-07-21    5.0  173.520000  2003.0    7.0  16.000000     2.000000
# 2003-07-22    6.0  172.464286  2003.0    7.0  17.571429     1.571429

# %%
df_vwap['VWAP'].plot()
df_vwap.rolling(window=30).mean()['VWAP'].plot(figsize=(16, 6))

# %%
#Checking for missing values
df_vwap.isnull().sum()
# Out:
# index           0
# VWAP            0
# year            0
# month           0
# day             0
# day of week     0
# Weekday Name    0
# dtype: int64
